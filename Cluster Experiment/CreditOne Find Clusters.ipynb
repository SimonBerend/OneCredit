# %% [markdown]
# # Libraries

# %%
# General
import pandas as pd
import numpy as np
from math import sqrt

# Clustering algorithm : DBSCAN 
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import minmax_scale

# plot result
import matplotlib.pyplot as plt

# %% [markdown]
# # Import Data

# %%
# Import Data
credit = pd.read_csv('Data/creditCleanAllBills.csv')

# %%
# iterating the columns
colnames = []
for col in credit.columns: 
    colnames.append(col)
# colnames

# %%
# Select Features
# see if there are regularities in limit, age and recent bill and payement info
# across other demografic characteristics
creditLimit = credit.loc[: , ['Limit', 'Sex', 'Marriage',
                         'Default']]

creditBill = credit.loc[: , ['Sex', 'Marriage',
                         'BillSep', 'Default']]

creditAge = credit.loc[: , [ 'Sex', 'Marriage', 'Age',
                         'Default']]

creditPaid = credit.loc[: , [ 'Sex', 'Marriage', 
                         'PaidSep',  'Default']]

# %% [markdown]
# # Prepare Cluster Alg

# %%
# use min/max normalization
# will create 8 groups based on
# sex-marriage-default
# and calculate split off values for the other variables

# MinMax (0-1) normalization
creditMM = minmax_scale(creditSelect)

# turn outcome into df
columns = creditSelect.columns # save names of columns
creditMM = pd.DataFrame(data = creditMM, columns = columns)

# %%
# alternative method : scale and centre
# Note : scale is based on mean and standard dev 
# Because scales between variables differs, its hard to make clusters with 
# (DBSCAN's eps value applies to all variables equally)
# more info : https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html#sklearn.preprocessing.StandardScaler

## Compute the mean and std
# scaler = StandardScaler().fit(credit)

## transform data with scale
# credit2 = scaler.transform(credit) 

## turn result into df
# columns = credit.columns 
# credit2 = pd.DataFrame(data = credit2, columns = columns)

# %%
creditMM.describe()
# Out:
#               Limit           Sex      Marriage           Age       BillSep  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean       0.159075      0.603733      0.544700      0.249750      0.191846
# std        0.131058      0.489129      0.498006      0.158929      0.065159
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.040404      0.000000      0.000000      0.120690      0.149668
# 50%        0.131313      1.000000      1.000000      0.224138      0.166324
# 75%        0.232323      1.000000      1.000000      0.344828      0.205887
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#             BillAug       BillJul       PaidSep       PaidAug       PaidJul  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean       0.112893      0.112157      0.006483      0.003516      0.005832
# std        0.067546      0.038076      0.018961      0.013680      0.019650
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.069053      0.087808      0.001145      0.000495      0.000435
# 50%        0.086340      0.097374      0.002404      0.001193      0.002009
# 75%        0.126964      0.119378      0.005731      0.002969      0.005028
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#             Default
# count  30000.000000
# mean       0.221200
# std        0.415062
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
# Compute DBSCAN

# note: unclear how to get clusters from this .fit() command
# use command below : fit_predict()

db = DBSCAN(eps = 0.4, min_samples = 100).fit(creditMM)
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)


print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)
# Out:
# Estimated number of clusters: 8
# Estimated number of noise points: 8

# %%
# save cluster info in a variable
creditMM["cluster"] = db.fit_predict(creditMM)

# %%
credit['cluster'] = creditMM['cluster']

# %%
# check distribution : obs / cluster
credit.groupby(["cluster"]).count()
# Out:
#          Limit   Sex  Education  Marriage   Age  StatusSep  StatusAug  \
# cluster
# -1           8     8          8         8     8          8          8
#  0        1860  1860       1860      1860  1860       1860       1860
#  1        1903  1903       1903      1903  1903       1903       1903
#  2        7738  7738       7738      7738  7738       7738       7738
#  3        6606  6606       6606      6606  6606       6606       6606
#  4        3843  3843       3843      3843  3843       3843       3843
#  5        5170  5170       5170      5170  5170       5170       5170
#  6        1527  1527       1527      1527  1527       1527       1527
#  7        1345  1345       1345      1345  1345       1345       1345
#
#          StatusJul  StatusJun  StatusMay  ...  BillJun  BillMay  BillApr  \
# cluster                                   ...
# -1               8          8          8  ...        8        8        8
#  0            1860       1860       1860  ...     1860     1860     1860
#  1            1903       1903       1903  ...     1903     1903     1903
#  2            7738       7738       7738  ...     7738     7738     7738
#  3            6606       6606       6606  ...     6606     6606     6606
#  4            3843       3843       3843  ...     3843     3843     3843
#  5            5170       5170       5170  ...     5170     5170     5170
#  6            1527       1527       1527  ...     1527     1527     1527
#  7            1345       1345       1345  ...     1345     1345     1345
#
#          PaidSep  PaidAug  PaidJul  PaidJun  PaidMay  PaidApr  Default
# cluster
# -1             8        8        8        8        8        8        8
#  0          1860     1860     1860     1860     1860     1860     1860
#  1          1903     1903     1903     1903     1903     1903     1903
#  2          7738     7738     7738     7738     7738     7738     7738
#  3          6606     6606     6606     6606     6606     6606     6606
#  4          3843     3843     3843     3843     3843     3843     3843
#  5          5170     5170     5170     5170     5170     5170     5170
#  6          1527     1527     1527     1527     1527     1527     1527
#  7          1345     1345     1345     1345     1345     1345     1345
#
# [9 rows x 24 columns]

# %%
# check mean values in clusters
creditMM.groupby(['cluster']).mean()

# so what did the cluster do?
# it checks common payment/billing/status/age values for :
# groups that can be created through binary values
# married men that default
# married women that default
# married women that pay
# etc.
# and splits the population based on those values
# ! importantly ! The values do not represent an approximation of the real values of
# observations in a group. They represent splitting criteria.
# Out:
#             Limit    Sex  Marriage       Age   BillSep   BillAug   BillJul  \
# cluster
# -1       0.511364  0.625     0.375  0.323276  0.446554  0.429976  0.417701
#  0       0.129277  1.000     0.000  0.310187  0.188958  0.110523  0.111068
#  1       0.119975  1.000     1.000  0.170792  0.186959  0.108559  0.110086
#  2       0.164508  1.000     1.000  0.177349  0.189797  0.110760  0.111104
#  3       0.179328  1.000     0.000  0.308176  0.191468  0.112431  0.111933
#  4       0.197159  0.000     0.000  0.358058  0.198678  0.118930  0.115701
#  5       0.144734  0.000     1.000  0.197519  0.193084  0.114085  0.112216
#  6       0.095227  0.000     1.000  0.193099  0.187786  0.109727  0.109931
#  7       0.141579  0.000     0.000  0.362646  0.195211  0.116721  0.114109
#
#           PaidSep   PaidAug   PaidJul  Default
# cluster
# -1       0.257312  0.391169  0.454046    0.125
#  0       0.003861  0.002110  0.003604    1.000
#  1       0.003863  0.001913  0.003497    1.000
#  2       0.006935  0.003589  0.006091    0.000
#  3       0.007196  0.003780  0.006107    0.000
#  4       0.007799  0.004392  0.007004    0.000
#  5       0.006866  0.003746  0.006298    0.000
#  6       0.003620  0.001907  0.003810    1.000
#  7       0.004250  0.002135  0.003863    1.000

# %%
dummies = pd.get_dummies(creditMM["cluster"])

# %%
# Save clusters

# as dummies
dummies.to_csv('Data/clusterDummies.csv', index = False)

# and as a single variable
creditMM["cluster"].to_csv('Data/clusterVariable.csv', index = False)
# Out:
# C:\Users\sbvan\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   import sys

# %%
# concatenate the original credit df with the dummies df
creditCluster = pd.concat([credit, dummies.loc[:, '0': '7']], axis = 1, sort = False)

# %%
# heat map : correlation matrix
# note : cluster are not highly correlated with status

creditCluster.corr().style.background_gradient(cmap = 'seismic',
                                               axis = None,
                                               low = 0.16).set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row0_col0 {
#             background-color:  #800000;
#             color:  #f1f1f1;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row0_col1 {
#             background-color:  #ffd5d5;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row0_col2 {
#             background-color:  #b1b1ff;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row0_col3 {
#             background-color:  #ededff;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row0_col4 {
#             background-color:  #ff9999;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row0_col5 {
#             background-color:  #9d9dff;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row0_col6 {
#             background-color:  #9191ff;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row0_col7 {
#             background-color:  #9595ff;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row0_col8 {
#             background-color:  #9d9dff;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row0_col9 {
#             background-color:  #a9a9ff;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row0_col10 {
#             background-color:  #adadff;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row0_col11 {
#             background-color:  #ff5555;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row0_col12 {
#             background-color:  #ff5959;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row0_col13 {
#             background-color:  #ff5959;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row0_col14 {
#             background-color:  #ff5151;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row0_col15 {
#             background-color:  #ff5151;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row0_col16 {
#             background-color:  #ff5555;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row0_col17 {
#             background-color:  #ff8181;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row0_col18 {
#             background-color:  #ff8989;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row0_col19 {
#             background-color:  #ff7979;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row0_col20 {
#             background-color:  #ff7d7d;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row0_col21 {
#             background-color:  #ff7575;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row0_col22 {
#             background-color:  #ff7575;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row0_col23 {
#             background-color:  #d5d5ff;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row0_col24 {
#             background-color:  #ffe9e9;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row0_col25 {
#             background-color:  #fffdfd;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row0_col26 {
#             background-color:  #f9f9ff;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row0_col27 {
#             background-color:  #ffd5d5;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row0_col28 {
#             background-color:  #ffb9b9;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row0_col29 {
#             background-color:  #ffa9a9;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row0_col30 {
#             background-color:  #fff9f9;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row0_col31 {
#             background-color:  #e9e9ff;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row0_col32 {
#             background-color:  #ffeded;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row1_col0 {
#             background-color:  #ffd5d5;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row1_col1 {
#             background-color:  #800000;
#             color:  #f1f1f1;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row1_col2 {
#             background-color:  #ffd9d9;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row1_col3 {
#             background-color:  #ffeded;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row1_col4 {
#             background-color:  #f5f5ff;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row1_col5 {
#             background-color:  #fff9f9;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row1_col6 {
#             background-color:  #fdfdff;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row1_col7 {
#             background-color:  #fffdfd;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row1_col8 {
#             background-color:  #fffdfd;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row1_col9 {
#             background-color:  #fff9f9;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row1_col10 {
#             background-color:  #fff5f5;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row1_col11 {
#             background-color:  #fff1f1;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row1_col12 {
#             background-color:  #ffeded;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row1_col13 {
#             background-color:  #ffe9e9;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row1_col14 {
#             background-color:  #ffe9e9;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row1_col15 {
#             background-color:  #ffe9e9;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row1_col16 {
#             background-color:  #ffe9e9;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row1_col17 {
#             background-color:  #ffe1e1;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row1_col18 {
#             background-color:  #ffe1e1;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row1_col19 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row1_col20 {
#             background-color:  #ffe1e1;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row1_col21 {
#             background-color:  #ffe1e1;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row1_col22 {
#             background-color:  #ffe1e1;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row1_col23 {
#             background-color:  #fff1f1;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row1_col24 {
#             background-color:  #0000ae;
#             color:  #f1f1f1;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row1_col25 {
#             background-color:  #ff7d7d;
#             color:  #000000;
#         }    #T_bdd05b82_48cd_11ea_a514_c8348e0fc477row1_col26 {
#             background-color:  #
